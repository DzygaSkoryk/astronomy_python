# %% [markdown]
# # Sloan Digital Sky Survey Assignment
#
# Sloan Digital Sky Survey dataset https://www.kaggle.com/lucidlenn/sloan-digital-sky-survey
#
# ### Preparation:
# - Register on Kaggle page
# - Make sure you has installed all nesessary libraries as well as Jupyter Notebook
#
# ### Task 1:
# 0. Go to Kaggle SDSS and read summary of the project.
# 1. Download dataset and read locally on your machine:
#     - df = pd.read_csv("data.csv")
# 2. Provide exploratory data analysis:
#    - Number of parameters / observations
#    - Unique entries
#    - Basic Description of Data statistics with Pandas (df.head(), df.describe() etc.)
#    - Explore NaN values
#    - Think about other useful information about the dataset
# 3. Create nice plots to vizualize the data
#    - Choose the best way to represent the data (line plot, scatter plot, bar plot etc.)
#    - Put titles, axis labels
#    - Choose apropriate axes limits
#
# #### Useful links:
#    - Matplot basics https://towardsdatascience.com/your-everyday-cheatsheet-for-pythons-matplotlib-c03345ca390d
#    - Exploratory Data Analysis https://towardsdatascience.com/exploratory-data-analysis-8fc1cb20fd15,
#    https://towardsdatascience.com/the-best-exploratory-data-analysis-with-pandas-profiling-e85b4d514583
#
# ![image.png](attachment:image.png)

# %%
350*0.75+300*0.75
# Out:
# 487.5

# %%
300+350
# Out:
# 650

# %%
650*0.25
# Out:
# 162.5

# %%
650-162
# Out:
# 488

# %%
650*0.75
# Out:
# 487.5
