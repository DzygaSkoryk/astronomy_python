# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
# load image
import matplotlib.image as mpimg 
star = mpimg.imread('star.png') 

print(type(star))
  
# Output Images 
plt.figure()
plt.imshow(star);
# Out:
# <class 'numpy.ndarray'>
# <img src="data:image/png;base64,..." width="639.4499999999999">

# %%
star.shape
# Out:
# (500, 500, 4)

# %%
plt.figure()
plt.imshow(star[:,:,3])
# Out:
# <img src="data:image/png;base64,..." width="639.4499999999999">

# %%
star1 = star[:,:,0].copy() # take one channel

# see index of maximum element
ind = np.unravel_index(np.argmax(star1), star1.shape)
ind
# Out:
# (227, 251)

# %%
# create mask and fill background with nan value
star1[star1<0.5] = np.nan

plt.figure()
plt.imshow(star1)
# Out:
# <img src="data:image/png;base64,..." width="639.4499999999999">

# %%
# mean value ignoring NaN 
np.nanmean(star1)
# Out:
# 0.86164737
