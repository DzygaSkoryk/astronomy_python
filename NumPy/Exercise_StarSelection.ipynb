# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
# load image
import matplotlib.image as mpimg 
star = mpimg.imread('star.png') 

print(type(star))
  
# Output Images 
plt.figure()
plt.imshow(star);
# Out:
# <class 'numpy.ndarray'>
# <img src="data:image/png;base64,..." width="640.1666666666666">

# %%
star.shape
# Out:
# (500, 500, 4)

# %%
# See what is in all channels
plt.figure()
plt.imshow(star[:,:,3])
# Out:
# <img src="data:image/png;base64,..." width="640.1666666666666">

# %%
star1 = star[:,:,0].copy() # take one channel

# see index of maximum element
ind = np.unravel_index(np.argmax(star1), star1.shape)
ind
# Out:
# (227, 251)

# %%
# create mask and fill background with nan value
star[star<0.5] = np.nan
#star1[(star1<0.5)&(star1>0.8)] = np.nan

plt.figure()
plt.imshow(star)
# Out:
# <img src="data:image/png;base64,..." width="640.1666666666666">

# %%
# mean value ignoring NaN 
np.nanmean(star)
# Out:
# 0.99537355

# %% [markdown]
# ### Now you perform the photometry in a circular aperture with a radius of 3 pixels
#
# Find the center of a star
#
# S
